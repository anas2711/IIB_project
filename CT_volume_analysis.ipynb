# %%
from mainfunctions import *

# %%
#retrieve sample photo
rgb_img = imageio.imread("3dwindow.png")
# display the photo
plt.imshow(rgb_img)
plt.show()

# %%
#convert the photo to grayscale
gray_img = cv.cvtColor(rgb_img, cv.COLOR_RGB2GRAY)
# display the photo
plt.imshow(gray_img, cmap='gray')
plt.show()
