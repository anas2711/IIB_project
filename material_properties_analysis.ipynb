# %%
#import plt
import numpy as np
import matplotlib.pyplot as plt

from postprocessing import *
from preprocessing import *
from mainfunctions2 import *

# %%
percentages= [0, 0, 11.996529180985188, 7.853215756552147, 6.905243668031397, 5.488348694680338, 4.128658132688222, 3.809121676546795, 0.284326595150701, 0.1894968705958642, 0.15038512527371253, 0.14520583833378392, 0.13682143212161244, 0.1312240861461739, 71.62075913946728, 0.0991496679217728, 0.04336201218316931, 80.20197825535604, 0.02554805217005155, 0.02132101081100666, 0.0006503140552376759]

means= [0, 0, 20.197377831739658, 15.335183941830543, 5.12431694312082, 1.632438113312068, 7.222990528959801, 22.329046232240465, 14.545007161148316, 23.207652665184224, 10.757329656186798, 23.86228406909789, 8.110365343364835, 39.89754909284335, 4.868518298543867, 13.405121641066827, 6.339417068380646, 4.968890589797727, 9.18487012987013, 14.235722066604419, 9.11011904761905]

stds= [0, 0, 18.95238796952638, 11.474070685315894, 0.47731818716437696, 0.33210908660821953, 12.566901101619584, 24.706455910384644, 15.473159423572712, 19.94424290105044, 3.5757866520417014, 39.62071601578664, 7.968007797927107, 59.50248864810705, 14.683551705353167, 11.115018453743179, 2.0822853634914447, 14.309610015687975, 2.7705124132159225, 16.92409995661376, 0.9687077106562165]

#plot means against std
plt.figure()
plt.scatter(means,stds)
plt.xlabel('mean')
plt.ylabel('std')
plt.title('mean against std')

#plot percentages against std
plt.figure()
plt.scatter(percentages,stds)
plt.xlabel('percentages')
plt.ylabel('std')
plt.title('percentages against std')

#percentagws against mean
plt.figure()
plt.scatter(percentages,means)
plt.xlabel('percentages')
plt.ylabel('means')
plt.title('percentages against means')
# Out:
# Text(0.5, 1.0, 'percentages against means')

# %%
roughness= np.zeros(len(means))
metallicness= np.zeros(len(means))

#metallicness relates to stds
for r in roughness:
    difference= means[r] - percentages[r]
    if difference< 0:
