# %%
from mainfunctions3 import *
from preprocessing import *
from postprocessing import *

# %%
specular = [
    [99.99946581, 6.57142566, 15.22830239],
    [0.071907, 44.19034322, 20.55058543],
    [0.1417456, 61.53597468, 28.95060976],
    [ 1.77386837 ,18.91634387 ,18.24666472],
    [ 0.09893665 ,33.67807201 ,22.15085462]
]

shiny = [
    [0.98671223, 20.36273112, 18.88556685],
    [99.90885534, 11.27258863, 28.25507896],
    [100.0, 11.33630017, 28.36391643],
    [99.98811259, 11.33466233, 28.36382264],
    [1.51296698, 14.94607534, 15.66064007],
    [99.91293249,  7.57308372, 15.57961226],
    [100. ,          7.59779012 , 15.61992878],
    [99.7983058  , 7.44891913, 15.27134248],
    [99.99731725 , 7.59710328 ,15.61955211]

]

diffuse = [
    [8.4068885, 0.81653351, 10.93480075],
    [21.52590619, 4.35386351, 15.30241054],
    [7.0733963, 15.93496746, 12.12216874],
    [5.93934149, 5.21239492, 0.41711265],
    [7.03737355, 16.35357963, 11.69805788],
    [5.48623517, 1.62950238, 0.25597201],
    [45.19786591, 9.16331805, 8.58531353],
    [100.0, 6.51623595, 9.35549376],
    [47.02994927,  2.77428834 , 3.79654982]
]

# not sure [92.86240841  5.83014802 15.21952234]

# %%
#plot 1 vs 2 column
plt.figure()
plt.scatter(specular[0], specular[1], color='red', label='Specular', marker='x')
plt.scatter(shiny[0], shiny[1], color='blue', label='Shiny', marker='x')
plt.scatter(diffuse[0], diffuse[1], color='green', label='Diffuse', marker='x')
plt.legend()
plt.xlabel('Percentage covered by specular component')
plt.ylabel('Mean of the intensity of specular component')
plt.show()


#plot 1 vs 3 column
plt.figure()
plt.scatter(specular[0], specular[2], color='red', label='Specular', marker='x')
plt.scatter(shiny[0], shiny[2], color='blue', label='Shiny', marker='x')
plt.scatter(diffuse[0], diffuse[2], color='green', label='Diffuse', marker='x')
plt.legend()
plt.xlabel('Percentage covered by specular component')
plt.ylabel('Standard deviation of the specular component')
plt.show()

#plot 2 vs 3 column
plt.figure()
plt.scatter(specular[1], specular[2], color='red', label='Specular', marker='x')
plt.scatter(shiny[1], shiny[2], color='blue', label='Shiny', marker='x')
plt.scatter(diffuse[1], diffuse[2], color='green', label='Diffuse', marker='x')
plt.legend()
plt.xlabel('Mean of the intensity of specular component')
plt.ylabel('Standard deviation of the specular component')
plt.show()
